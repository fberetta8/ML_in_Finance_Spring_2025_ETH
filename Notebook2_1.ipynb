# %% [markdown]
# <a href="https://colab.research.google.com/github/fberetta8/ML_in_Finance_Spring_2025_ETH/blob/main/Notebook2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Controlled ODEs as features on the path space

# %% [markdown]
# In this notebook, we will investigate the effects of various control strategies on a controlled ODE (CODE). The system is controlled by different types of inputs, and we will solve the system both with and without control. By visualizing the results, we can observe how each type of control influences the system's behavior. Notably, CODE define (non-linear) features on the path space where the system lies, namely $\mathcal{C}^1([0,20], \mathbb{R}^2)$.
#
# The system is described by the following controlled ODE:
# $$ \dot{x}_1 = x_2 $$
# $$ \dot{x}_2 = -x_1^3 + \cos(x_1) + u(t) $$
#
# Where:
# - $x_1$ is the position,
# - $x_2$ is the velocity,
# - \$u(t)$ is the control input.
#
# We will explore five different control inputs and solve the system's equations numerically.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# Define a controlled nonlinear ODE
def controlled_ode(t, x, u_func):
    u = u_func(t)
    return np.array([x[1], -x[0]**3 + np.cos(x[0]) + u])

# %% [markdown]
# ## Control Strategies
#
# We define several control strategies to manipulate the system’s dynamics in different ways:
# 1. **Oscillatory Control**: $ u(t) = \sin(3t) $
#
# 2. **Saturating Control**:
#    $ u(t) = \tanh(0.5t) $
#
# 3. **Exponential Decay Control**: $ u(t) = e^{-0.1t} - 1 $
#
# 4. **Linearly Growing Oscillatory Control**: $ u(t) = 0.2t \cos(0.5t) $
#
# 5. **No Control**
#
# The system is solved numerically to compare their impacts on the dynamics.

# %%
  # TODO: Define the 5 controls

# %%
# Solve the system
T_span = (0, 20)
t_eval = np.linspace(T_span[0], T_span[1], 400)
x0 = [1, 0]  # Initial condition

  # TODO: Solve numerically the system with the 5 different controls.
  # Hint: Check among the imported packages for ideas.

# %%
# Plot position (x1) for each control strategy
plt.figure(figsize=(8, 4))

  # TODO: Plot the position (x1) against time for the 5 evolving systems.
